# %% [markdown]
# ## Funciones de limpieza

# %%
import pandas as pd
import numpy as np
import os

# %%
def createDummies (dataframe, var_name):
    try:
        dummy =pd.get_dummies(data[var_name], prefix=var_name)
        dataframe = dataframe.drop([var_name], axis = 1)
        dataframe = pd.concat([dataframe, dummy], axis = 1)
    except KeyError as e:
        print("Key {} not found in dataframe: KeyError""{}""".format(var_name, e))
    return dataframe

def is_number(s):
    try:
        float(s)
        return True
    except ValueError:
        return False

def fillColumn (dataframe, column, value):
    if value == "mean":
        dataframe[column] = dataframe[column].fillna(data[column].mean()) 
    elif is_number(value):
        dataframe[column] = dataframe[column].fillna(float(value))
    else:
        dataframe[column] = dataframe[column].fillna(value)
    return dataframe

# %%
dspath = "../../datasets"
ccm = "customer-churn-model/Customer Churn Model.txt"
titanic = "titanic/titanic3.csv"
ccmpath = os.path.join(dspath, ccm)
titanicpath = os.path.join(dspath, titanic)

# %%
titanicdt = pd.read_csv(titanicpath)

# %%
titanicdt = fillColumn(data, "body", 0)
titanicdt = fillColumn(data, "home.dest", "Unknown")
titanicdt = fillColumn(data, "cabin", "Unknown")
titanicdt = fillColumn(data, "boat", "Unknown")
titanicdt = fillColumn(data, "age", "mean")

# %%
   
titanicdt = createDummies (data, "sex")
titanicdt = createDummies (data, "embarked")
# Out:
# Key sex not found in dataframe: KeyError'sex'
# Key embarked not found in dataframe: KeyError'embarked'

# %%
titanicdt
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#             age  sibsp  parch  ticket      fare    cabin     boat   body  \
# ...
