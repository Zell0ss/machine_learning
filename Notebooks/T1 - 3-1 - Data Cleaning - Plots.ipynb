# %% [markdown]
# ## Plots y visualización de datos

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
def createDummies (dataframe, var_name):
    try:
        dummy =pd.get_dummies(data[var_name], prefix=var_name)
        dataframe = dataframe.drop([var_name], axis = 1)
        dataframe = pd.concat([dataframe, dummy], axis = 1)
    except KeyError as e:
        print("Key {} not found in dataframe: KeyError""{}""".format(var_name, e))
    return dataframe

def is_number(s):
    try:
        float(s)
        return True
    except ValueError:
        return False

def fillColumn (dataframe, column, value):
    if value == "mean":
        dataframe[column] = dataframe[column].fillna(data[column].mean()) 
    elif is_number(value):
        dataframe[column] = dataframe[column].fillna(float(value))
    else:
        dataframe[column] = dataframe[column].fillna(value)
    return dataframe

# %%
dspath = "../../datasets"
ccm = "customer-churn-model/Customer Churn Model.txt"

ccmpath = os.path.join(dspath, ccm)

# %%
data  = pd.read_csv(ccmpath)
data
# Out:
#      State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0       KS             128        415  382-4657         no        yes
# 1       OH             107        415  371-7191         no        yes
# 2       NJ             137        415  358-1921         no         no
# 3       OH              84        408  375-9999        yes         no
# 4       OK              75        415  330-6626        yes         no
# ...    ...             ...        ...       ...        ...        ...
# 3328    AZ             192        415  414-4276         no        yes
# 3329    WV              68        415  370-3271         no         no
# 3330    RI              28        510  328-8230         no         no
# 3331    CT             184        510  364-6381        yes         no
# 3332    TN              74        415  400-4344         no        yes
#
#       VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  \
# ...

# %%
data.describe()
# Out:
#        Account Length    Area Code  VMail Message     Day Mins    Day Calls  \
# count     3333.000000  3333.000000    3333.000000  3333.000000  3333.000000
# mean       101.064806   437.182418       8.099010   179.775098   100.435644
# std         39.822106    42.371290      13.688365    54.467389    20.069084
# min          1.000000   408.000000       0.000000     0.000000     0.000000
# 25%         74.000000   408.000000       0.000000   143.700000    87.000000
# 50%        101.000000   415.000000       0.000000   179.400000   101.000000
# 75%        127.000000   510.000000      20.000000   216.400000   114.000000
# max        243.000000   510.000000      51.000000   350.800000   165.000000
#
#         Day Charge     Eve Mins    Eve Calls   Eve Charge   Night Mins  \
# count  3333.000000  3333.000000  3333.000000  3333.000000  3333.000000
# mean     30.562307   200.980348   100.114311    17.083540   200.872037
# ...

# %%
% matplotlib inline

# %%
#savefig("path_donde_guardar_im.jpeg")

# %% [markdown]
# ## Scatter Plot

# %%
data.plot(kind="scatter", x="Day Mins", y ="Day Charge" )

# %%
data.plot(kind="scatter", x="Night Mins", y ="Night Charge" )
plt.savefig(dspath+"/customer-churn-model/1.jpeg")

# %%
figure, axmins = plt.subplots(1,2, sharey=True, sharex=True)

data.plot(kind="scatter", y = "Day Mins", x ="Day Charge" , ax=axmins[0])
data.plot(kind="scatter", y = "Night Mins", x ="Night Charge", ax=axmins[1] )
plt.savefig(dspath+"/customer-churn-model/2.jpeg")

figure, axcalls = plt.subplots(1,2, sharey=True, sharex=True)

data.plot(kind="scatter", y = "Day Calls", x ="Day Charge" , ax=axcalls[0])
data.plot(kind="scatter", y = "Night Calls", x ="Night Charge", ax=axcalls[1] )
plt.savefig(dspath+"/customer-churn-model/3.jpeg")

# %% [markdown]
# ## Histograma de frecuencia
# La *regla de Sturges*, propuesta por Herbert Sturges en 1926, es una regla práctica acerca del número de clases que deben considerar al elaborarse un histograma.
#
# Este número viene dado por la siguiente expresión:
# ````
# c=1+(log(M)/log(2))
# ````
# o en log2
# ````
# c=1+log2(M)
# ````
# donde M es el tamaño de la muestra. Si no ponemos nada en bins, hist será pintado con la regla de sturges

# %%
sturges = 1 + np.log2(data["Day Calls"].count())

plt.hist(data["Day Calls"], bins = int(sturges))
plt.xlabel("Num. Llamadas/dia")
plt.ylabel("Frecuancia en los datos")
plt.title("Histograma de número de llamadas al día")
plt.savefig(dspath+"/customer-churn-model/4.jpeg")

# %% [markdown]
# ### Boxplot, diagrama de cajas y bigotes
#
# La caja se situa desde el primer quantil (25%) hasta el tercero (75%). La diferencia entre estos dos quantiles es el IQR *inter quantil ratio*
#
# En el medio marcamos la *moda*, o valor que más se repite y luego los "*bigotes*" se alargan a 1.5 del IQR. Esto nos marca los valores típicos, con las excepciones en forma de bolitas fuera de el.

# %%
data["Day Calls"].describe()
# Out:
# count    3333.000000
# mean      100.435644
# std        20.069084
# min         0.000000
# 25%        87.000000
# 50%       101.000000
# 75%       114.000000
# max       165.000000
# Name: Day Calls, dtype: float64

# %%
plt.boxplot(data["Day Calls"])
plt.ylabel("Número de llamadas diarias")
plt.title("Boxplot de las llamadas diarias")

plt.savefig(dspath+"/customer-churn-model/5.jpeg")

# %%
IQR=data["Day Calls"].quantile(0.75)-data["Day Calls"].quantile(0.25)  # interquantile data
IQR
# Out:
# 27.0
